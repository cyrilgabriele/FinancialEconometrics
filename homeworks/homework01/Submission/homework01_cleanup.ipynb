# %% [markdown]
# # Financial Econometrics — Homework 1
# **Solved by: Cyril Gabriele, Adriano Lama**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
from homework01_cleanup import (
    monthly_log_return, wti_plots, testing_avg_ret_stoxx,
    testing_CI_avg_ret_gold, correlation_matrix_risky_assets,
    highest_kurtoisis, plot_kutosis_vs_normal, highest_jarque_bera,
    hike_cut_identification, label_hiking_months, analyze_monetary_regimes
)
# Out:
# c:\Users\adria\HSG\FinancialEconometrics\homeworks\homework01\homework01_cleanup.py:328: SyntaxWarning: invalid escape sequence '\h'
#   df = pd.read_csv("homeworks\homework01\s1_data_hw.csv", encoding="utf-8-sig")

# %% [markdown]
# ## 1. Import Data

# %%
df = pd.read_csv("./s1_data_hw.csv", encoding="utf-8-sig")
df.head()
# Out:
#        Date  SXXP Index  SPY US INDEX  NKY INDEX  XAU CURNCY  CL1 COMDTY  \
# 0  12/31/08   276.76878         90.24   98.07993      875.43       44.60
# 1   1/30/09   245.27160         82.83   88.89192      927.85       41.68
# 2   2/27/09   219.88507         73.93   77.26031      942.32       44.76
# 3   3/31/09   233.43893         79.52   81.62587      919.90       49.66
# 4   4/30/09   264.48381         87.42   89.27354      887.95       51.12
#
#        SPDIV    RF  DFEDTARU
# 0  28.390000  2.87      0.25
# 1  28.013333  3.02      0.25
# 2  27.636667  2.71      0.25
# 3  27.260000  3.16      0.25
# 4  26.703333  3.47      0.25

# %% [markdown]
# ## 2. Monthly Log Returns (from Jan 2011)

# %%
monthly_returns, df_adjusted = monthly_log_return(df)
monthly_returns.head()
# Out:
# Mean monthly log return STOXX600: 0.0035
# Mean monthly log return NIKKEI: 0.0053
#         Date  RF_monthly  SP500_monthly_log_return  \
# 0 2011-01-31    0.002850                  0.023033
# 1 2011-02-28    0.002892                  0.034148
# 2 2011-03-31    0.002767                 -0.004215
# 3 2011-04-29    0.002542                  0.028550
# 4 2011-05-31    0.002650                 -0.011278
#
#    STOXX600_monthly_log_return  NIKKEI_monthly_log_return  \
# 0                     0.039719                  -0.001930
# 1                     0.029578                   0.038491
# 2                    -0.009147                  -0.097236
# 3                     0.072006                   0.025106
# 4                    -0.041080                  -0.013265
#
#    GOLD_monthly_log_return  WTI_monthly_log_return
# 0                -0.061109                0.008825
# 1                 0.054389                0.050550
# 2                 0.018178                0.095807
# 3                 0.083955                0.065376
# 4                -0.017723               -0.103772

# %% [markdown]
# ## 3. WTI Price & Return Plots

# %%
wti_plots(df_adjusted)
# Out:
# WTI returns show a spike of -78.19% around Mar 2020, highlighting the volatility.

# %% [markdown]
# ## 4. Hypothesis Test — STOXX600 Mean Return

# %%
testing_avg_ret_stoxx(monthly_returns)
# Out:
# t-statistic: 0.9994
# p-value: 0.3190
# FAILED TO REJECT H_0

# %% [markdown]
# ## 5. 95% Confidence Interval — GOLD Mean Return

# %%
testing_CI_avg_ret_gold(monthly_returns)
# Out:
# 95% CI lower bound: -0.0004
# 95% CI upper bound: 0.0128
# Average monthly risk-free rate: 0.0021
# Cannot claim Gold outperformed the risk-free rate at the 95% confidence level.

# %% [markdown]
# ## 6. Correlation Matrix

# %%
correlation_matrix = correlation_matrix_risky_assets(monthly_returns)
correlation_matrix
# Out:
#                              SP500_monthly_log_return  \
# SP500_monthly_log_return                     1.000000
# STOXX600_monthly_log_return                  0.818141
# NIKKEI_monthly_log_return                    0.712742
# GOLD_monthly_log_return                      0.100748
# WTI_monthly_log_return                       0.403056
#
#                              STOXX600_monthly_log_return  \
# SP500_monthly_log_return                        0.818141
# STOXX600_monthly_log_return                     1.000000
# NIKKEI_monthly_log_return                       0.691802
# GOLD_monthly_log_return                         0.216826
# WTI_monthly_log_return                          0.441159
#
#                              NIKKEI_monthly_log_return  \
# SP500_monthly_log_return                      0.712742
# STOXX600_monthly_log_return                   0.691802
# NIKKEI_monthly_log_return                     1.000000
# GOLD_monthly_log_return                       0.037950
# WTI_monthly_log_return                        0.296861
#
#                              GOLD_monthly_log_return  WTI_monthly_log_return
# SP500_monthly_log_return                    0.100748                0.403056
# STOXX600_monthly_log_return                 0.216826                0.441159
# NIKKEI_monthly_log_return                   0.037950                0.296861
# GOLD_monthly_log_return                     1.000000                0.031111
# WTI_monthly_log_return                      0.031111                1.000000

# %%
wti_max_corr = (
    correlation_matrix["WTI_monthly_log_return"]
    .drop("WTI_monthly_log_return")
    .idxmax()
)
print(f"WTI most correlated with: {wti_max_corr}")

sp500_max_corr = (
    correlation_matrix["SP500_monthly_log_return"]
    .drop("SP500_monthly_log_return")
    .idxmax()
)
print(f"SP500 most correlated with: {sp500_max_corr}")
# Out:
# WTI most correlated with: STOXX600_monthly_log_return
# SP500 most correlated with: STOXX600_monthly_log_return

# %% [markdown]
# ## 7. Excess Kurtosis

# %%
asset_name_max_kurt, value_max_kurt = highest_kurtoisis(monthly_returns)
print(f"Highest excess kurtosis: {asset_name_max_kurt} = {value_max_kurt:.4f}")
# Out:
# Highest excess kurtosis: WTI_monthly_log_return = 15.7320

# %%
plot_kutosis_vs_normal(monthly_returns, asset_name_max_kurt)

# %% [markdown]
# ## 8. Jarque-Bera Test

# %%
asset_jb, stat_jb, pval_jb = highest_jarque_bera(monthly_returns)
print(f"Farthest from normal: {asset_jb}")
print(f"JB statistic: {stat_jb:.4f}, p-value: {pval_jb}")
# Out:
# Farthest from normal: WTI_monthly_log_return
# JB statistic: 1772.8998, p-value: 0.0

# %% [markdown]
# ## 9. Federal Reserve Hiking Cycles

# %% [markdown]
# ### 9a) Identify hiking-cycle months

# %%
df_hike_cut = hike_cut_identification(df)
df_cycles = label_hiking_months(df_hike_cut)

num_hiking_months = (df_cycles["D_t"] == 1).sum()
print(f"Total hiking-cycle months (sum of D_t): {num_hiking_months}")
# Out:
# Total hiking-cycle months (sum of D_t): 43

# %% [markdown]
# ### 9b–e) Total Return, Hiking vs Easing, Two-Sample t-Test

# %%
df_regimes = analyze_monetary_regimes(df, df_cycles)
# Out:
#  Question 9:
# 9. b) Std Dev of SP500 Total Return: 0.0435
# 9. c) Hiking Cycles -> Mean: 0.0218, IQR: 0.0327
# 9. d) Easing/Pause Cycles -> Mean: 0.0278, IQR: 0.0542
# 9. e) t-test -> t-statistic: -0.7986, p-value: 0.4254
#      Result: Fail to reject H_0. Returns are NOT significantly different at the 5% level.
